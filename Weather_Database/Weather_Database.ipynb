# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
skipped_count = 0
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
      # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description, 
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        skipped_count +=1
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dargaville
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | brigantine
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | jatiroto
# Processing Record 8 of Set 1 | muroto
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | katsuura
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | lompoc
# Processing Record 19 of Set 1 | opuwo
# Processing Record 20 of Set 1 | khoy
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | temirtau
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | karmala
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | qui nhon
# Processing Record 29 of Set 1 | bluefields
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | kruisfontein
# Processing Record 32 of Set 1 | rawson
# Processing Record 33 of Set 1 | taoudenni
# Processing Record 34 of Set 1 | antofagasta
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | pangnirtung
# Processing Record 39 of Set 1 | itoman
# Processing Record 40 of Set 1 | kahului
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 1 | thessalon
# Processing Record 44 of Set 1 | charters towers
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | khasan
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | portland
# Processing Record 1 of Set 2 | mokobeng
# Processing Record 2 of Set 2 | raga
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | esperance
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | mafinga
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | hirara
# Processing Record 11 of Set 2 | inhambane
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | orocue
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | mirabad
# Processing Record 16 of Set 2 | bandarbeyla
# Processing Record 17 of Set 2 | geraldton
# Processing Record 18 of Set 2 | nioro
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | alice springs
# Processing Record 21 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | requena
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 2 | key biscayne
# Processing Record 28 of Set 2 | codrington
# Processing Record 29 of Set 2 | nizwa
# Processing Record 30 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 2 | prestea
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | itarema
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | lengshuitan
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | praya
# Processing Record 38 of Set 2 | bahia blanca
# Processing Record 39 of Set 2 | bilibino
# Processing Record 40 of Set 2 | walvis bay
# Processing Record 41 of Set 2 | jiaozuo
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | pedernales
# Processing Record 44 of Set 2 | kutum
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | tilichiki
# Processing Record 47 of Set 2 | yulara
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | kumta
# Processing Record 2 of Set 3 | tautira
# Processing Record 3 of Set 3 | warmbad
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | klyuchi
# Processing Record 6 of Set 3 | sitka
# Processing Record 7 of Set 3 | bahia honda
# Processing Record 8 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | tecoanapa
# Processing Record 11 of Set 3 | rizhao
# Processing Record 12 of Set 3 | noumea
# Processing Record 13 of Set 3 | flinders
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | olafsvik
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | dom pedro
# Processing Record 18 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 3 | krasnoselkup
# Processing Record 20 of Set 3 | olga
# Processing Record 21 of Set 3 | coahuayana
# Processing Record 22 of Set 3 | braniewo
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | tagusao
# Processing Record 25 of Set 3 | belaya gora
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | ngunguru
# Processing Record 28 of Set 3 | parabel
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | sayyan
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | panzhihua
# Processing Record 33 of Set 3 | boddam
# Processing Record 34 of Set 3 | colesberg
# Processing Record 35 of Set 3 | tonami
# Processing Record 36 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 3 | sereflikochisar
# Processing Record 38 of Set 3 | nuevo ideal
# Processing Record 39 of Set 3 | nuuk
# Processing Record 40 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 3 | westport
# Processing Record 43 of Set 3 | chara
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | garowe
# Processing Record 46 of Set 3 | anito
# Processing Record 47 of Set 3 | alibag
# Processing Record 48 of Set 3 | aketi
# Processing Record 49 of Set 3 | whitehaven
# Processing Record 50 of Set 3 | digha
# Processing Record 1 of Set 4 | oktyabrskoye
# Processing Record 2 of Set 4 | rio gallegos
# Processing Record 3 of Set 4 | naples
# Processing Record 4 of Set 4 | zhigalovo
# Processing Record 5 of Set 4 | tabou
# Processing Record 6 of Set 4 | hami
# Processing Record 7 of Set 4 | qixingtai
# Processing Record 8 of Set 4 | abu samrah
# Processing Record 9 of Set 4 | yagodnoye
# Processing Record 10 of Set 4 | ust-kuyga
# Processing Record 11 of Set 4 | husavik
# Processing Record 12 of Set 4 | saint-georges
# Processing Record 13 of Set 4 | ocala
# Processing Record 14 of Set 4 | namatanai
# Processing Record 15 of Set 4 | severo-kurilsk
# Processing Record 16 of Set 4 | korem
# Processing Record 17 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 4 | tual
# Processing Record 20 of Set 4 | julio de castilhos
# Processing Record 21 of Set 4 | aromashevo
# Processing Record 22 of Set 4 | big spring
# Processing Record 23 of Set 4 | jiangyou
# Processing Record 24 of Set 4 | eau claire
# Processing Record 25 of Set 4 | ahipara
# Processing Record 26 of Set 4 | chokurdakh
# Processing Record 27 of Set 4 | poum
# Processing Record 28 of Set 4 | nouadhibou
# Processing Record 29 of Set 4 | san luis
# Processing Record 30 of Set 4 | laguna
# Processing Record 31 of Set 4 | cherskiy
# Processing Record 32 of Set 4 | sawtell
# Processing Record 33 of Set 4 | bonthe
# Processing Record 34 of Set 4 | torbay
# Processing Record 35 of Set 4 | khorixas
# Processing Record 36 of Set 4 | chimoio
# Processing Record 37 of Set 4 | isangel
# Processing Record 38 of Set 4 | buritizeiro
# Processing Record 39 of Set 4 | altamira
# Processing Record 40 of Set 4 | port macquarie
# Processing Record 41 of Set 4 | amahai
# Processing Record 42 of Set 4 | diego de almagro
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | nhulunbuy
# Processing Record 45 of Set 4 | lazaro cardenas
# Processing Record 46 of Set 4 | pakwach
# City not found. Skipping...
# Processing Record 47 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 4 | maibong
# Processing Record 49 of Set 4 | sao jose da coroa grande
# Processing Record 50 of Set 4 | houston
# Processing Record 1 of Set 5 | mattru
# Processing Record 2 of Set 5 | talcahuano
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | saint andrews
# Processing Record 5 of Set 5 | paucartambo
# City not found. Skipping...
# Processing Record 6 of Set 5 | yar-sale
# Processing Record 7 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 8 of Set 5 | harwich
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | qaanaaq
# Processing Record 11 of Set 5 | college
# Processing Record 12 of Set 5 | maceio
# Processing Record 13 of Set 5 | komsomolskiy
# Processing Record 14 of Set 5 | berlevag
# Processing Record 15 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 5 | da nang
# Processing Record 17 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 5 | edgewater
# Processing Record 19 of Set 5 | schwedt
# Processing Record 20 of Set 5 | riverton
# Processing Record 21 of Set 5 | dicabisagan
# Processing Record 22 of Set 5 | paamiut
# Processing Record 23 of Set 5 | qasigiannguit
# Processing Record 24 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 5 | emerald
# Processing Record 26 of Set 5 | krasnovishersk
# Processing Record 27 of Set 5 | mpongwe
# Processing Record 28 of Set 5 | tateyama
# Processing Record 29 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | bucak
# Processing Record 32 of Set 5 | derzhavinsk
# Processing Record 33 of Set 5 | vao
# Processing Record 34 of Set 5 | yerbogachen
# Processing Record 35 of Set 5 | lydenburg
# Processing Record 36 of Set 5 | vila franca do campo
# Processing Record 37 of Set 5 | taunggyi
# Processing Record 38 of Set 5 | adrar
# Processing Record 39 of Set 5 | san cristobal
# Processing Record 40 of Set 5 | fort gloster
# Processing Record 41 of Set 5 | luanda
# Processing Record 42 of Set 5 | dunedin
# Processing Record 43 of Set 5 | klaksvik
# Processing Record 44 of Set 5 | babu
# Processing Record 45 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | khatanga
# Processing Record 47 of Set 5 | non sung
# Processing Record 48 of Set 5 | cidreira
# Processing Record 49 of Set 5 | kamnik
# Processing Record 50 of Set 5 | ferrol
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | quesnel
# Processing Record 3 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 6 | skibbereen
# Processing Record 5 of Set 6 | roald
# Processing Record 6 of Set 6 | sheksna
# Processing Record 7 of Set 6 | cabo san lucas
# Processing Record 8 of Set 6 | henties bay
# Processing Record 9 of Set 6 | viedma
# Processing Record 10 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 6 | tornio
# Processing Record 12 of Set 6 | banda aceh
# Processing Record 13 of Set 6 | saltpond
# Processing Record 14 of Set 6 | constitucion
# Processing Record 15 of Set 6 | hamilton
# Processing Record 16 of Set 6 | caravelas
# Processing Record 17 of Set 6 | srednekolymsk
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | williams lake
# Processing Record 20 of Set 6 | miri
# Processing Record 21 of Set 6 | ojinaga
# Processing Record 22 of Set 6 | stolin
# Processing Record 23 of Set 6 | collie
# Processing Record 24 of Set 6 | luderitz
# Processing Record 25 of Set 6 | avera
# Processing Record 26 of Set 6 | kaitangata
# Processing Record 27 of Set 6 | gat
# Processing Record 28 of Set 6 | beringovskiy
# Processing Record 29 of Set 6 | ponta do sol
# Processing Record 30 of Set 6 | deputatskiy
# Processing Record 31 of Set 6 | zhenlai
# Processing Record 32 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 6 | morondava
# Processing Record 34 of Set 6 | alyangula
# Processing Record 35 of Set 6 | tibacuy
# Processing Record 36 of Set 6 | baie-comeau
# Processing Record 37 of Set 6 | juliaca
# Processing Record 38 of Set 6 | dubai
# Processing Record 39 of Set 6 | iquique
# Processing Record 40 of Set 6 | talara
# Processing Record 41 of Set 6 | ninghai
# Processing Record 42 of Set 6 | grand gaube
# Processing Record 43 of Set 6 | athabasca
# Processing Record 44 of Set 6 | diffa
# Processing Record 45 of Set 6 | clyde river
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | pueblo
# Processing Record 48 of Set 6 | omboue
# Processing Record 49 of Set 6 | gravdal
# Processing Record 50 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | port-gentil
# Processing Record 3 of Set 7 | vostok
# Processing Record 4 of Set 7 | linjiang
# Processing Record 5 of Set 7 | provideniya
# Processing Record 6 of Set 7 | annau
# Processing Record 7 of Set 7 | port elizabeth
# Processing Record 8 of Set 7 | verkhnevilyuysk
# Processing Record 9 of Set 7 | belyy yar
# Processing Record 10 of Set 7 | punta de piedra
# Processing Record 11 of Set 7 | saldanha
# Processing Record 12 of Set 7 | ust-maya
# Processing Record 13 of Set 7 | san patricio
# Processing Record 14 of Set 7 | usogorsk
# Processing Record 15 of Set 7 | adelaide
# Processing Record 16 of Set 7 | vallenar
# Processing Record 17 of Set 7 | anadyr
# Processing Record 18 of Set 7 | liling
# Processing Record 19 of Set 7 | salalah
# Processing Record 20 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 7 | richards bay
# Processing Record 22 of Set 7 | ancud
# Processing Record 23 of Set 7 | axim
# Processing Record 24 of Set 7 | norman wells
# Processing Record 25 of Set 7 | plettenberg bay
# Processing Record 26 of Set 7 | xuddur
# Processing Record 27 of Set 7 | lao cai
# Processing Record 28 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 29 of Set 7 | tiksi
# Processing Record 30 of Set 7 | haines junction
# Processing Record 31 of Set 7 | stawell
# Processing Record 32 of Set 7 | troitskoye
# Processing Record 33 of Set 7 | natal
# Processing Record 34 of Set 7 | sambava
# Processing Record 35 of Set 7 | ambilobe
# Processing Record 36 of Set 7 | doka
# Processing Record 37 of Set 7 | ouro branco
# Processing Record 38 of Set 7 | mbini
# Processing Record 39 of Set 7 | buraydah
# Processing Record 40 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 7 | beohari
# Processing Record 42 of Set 7 | goedereede
# Processing Record 43 of Set 7 | dzerzhinsk
# Processing Record 44 of Set 7 | nevsehir
# Processing Record 45 of Set 7 | chipping sodbury
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | kongolo
# Processing Record 48 of Set 7 | wenchi
# Processing Record 49 of Set 7 | grindavik
# Processing Record 50 of Set 7 | qena
# Processing Record 1 of Set 8 | hokitika
# Processing Record 2 of Set 8 | saint-joseph
# Processing Record 3 of Set 8 | gamba
# Processing Record 4 of Set 8 | ucluelet
# Processing Record 5 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 8 | tiznit
# Processing Record 7 of Set 8 | santa rosa
# Processing Record 8 of Set 8 | arnprior
# Processing Record 9 of Set 8 | touros
# Processing Record 10 of Set 8 | salinas
# Processing Record 11 of Set 8 | half moon bay
# Processing Record 12 of Set 8 | sioux lookout
# Processing Record 13 of Set 8 | los llanos de aridane
# Processing Record 14 of Set 8 | vanimo
# Processing Record 15 of Set 8 | hasaki
# Processing Record 16 of Set 8 | ciudad bolivar
# Processing Record 17 of Set 8 | bachaquero
# Processing Record 18 of Set 8 | mercedes
# Processing Record 19 of Set 8 | bud
# Processing Record 20 of Set 8 | san martin
# Processing Record 21 of Set 8 | areia branca
# Processing Record 22 of Set 8 | hovd
# Processing Record 23 of Set 8 | storslett
# Processing Record 24 of Set 8 | katerero
# Processing Record 25 of Set 8 | sura
# Processing Record 26 of Set 8 | beech grove
# Processing Record 27 of Set 8 | isla mujeres
# Processing Record 28 of Set 8 | roma
# Processing Record 29 of Set 8 | leshukonskoye
# Processing Record 30 of Set 8 | nioki
# Processing Record 31 of Set 8 | sorland
# Processing Record 32 of Set 8 | esperantinopolis
# Processing Record 33 of Set 8 | vanavara
# Processing Record 34 of Set 8 | oksfjord
# Processing Record 35 of Set 8 | tamiahua
# Processing Record 36 of Set 8 | nueve de julio
# Processing Record 37 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | taguatinga
# Processing Record 40 of Set 8 | buala
# Processing Record 41 of Set 8 | vila velha
# Processing Record 42 of Set 8 | santa cruz cabralia
# Processing Record 43 of Set 8 | lubango
# Processing Record 44 of Set 8 | briancon
# Processing Record 45 of Set 8 | tobane
# Processing Record 46 of Set 8 | rongcheng
# Processing Record 47 of Set 8 | tshela
# Processing Record 48 of Set 8 | matay
# Processing Record 49 of Set 8 | zaria
# Processing Record 50 of Set 8 | jesus
# Processing Record 1 of Set 9 | zhigansk
# Processing Record 2 of Set 9 | sisimiut
# Processing Record 3 of Set 9 | pevek
# Processing Record 4 of Set 9 | puerto madryn
# Processing Record 5 of Set 9 | lopukhiv
# Processing Record 6 of Set 9 | kungurtug
# Processing Record 7 of Set 9 | coquimbo
# Processing Record 8 of Set 9 | west des moines
# Processing Record 9 of Set 9 | kalmunai
# Processing Record 10 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 9 | namibe
# Processing Record 12 of Set 9 | san-pedro
# Processing Record 13 of Set 9 | bilma
# Processing Record 14 of Set 9 | sur
# Processing Record 15 of Set 9 | kysyl-syr
# Processing Record 16 of Set 9 | ostrovnoy
# Processing Record 17 of Set 9 | canaries
# Processing Record 18 of Set 9 | catalina
# Processing Record 19 of Set 9 | wenling
# Processing Record 20 of Set 9 | beloha
# Processing Record 21 of Set 9 | urumqi
# Processing Record 22 of Set 9 | korla
# Processing Record 23 of Set 9 | champua
# Processing Record 24 of Set 9 | channel-port aux basques
# Processing Record 25 of Set 9 | liverpool
# Processing Record 26 of Set 9 | beruwala
# Processing Record 27 of Set 9 | maningrida
# Processing Record 28 of Set 9 | saint anthony
# Processing Record 29 of Set 9 | olinda
# Processing Record 30 of Set 9 | port blair
# Processing Record 31 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 9 | narsaq
# Processing Record 33 of Set 9 | antalaha
# Processing Record 34 of Set 9 | oistins
# Processing Record 35 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 9 | kieta
# Processing Record 37 of Set 9 | dingle
# Processing Record 38 of Set 9 | spornoye
# Processing Record 39 of Set 9 | seoul
# Processing Record 40 of Set 9 | baruun-urt
# Processing Record 41 of Set 9 | nome
# Processing Record 42 of Set 9 | asau
# Processing Record 43 of Set 9 | ilulissat
# Processing Record 44 of Set 9 | port hardy
# Processing Record 45 of Set 9 | cayenne
# Processing Record 46 of Set 9 | izumo
# Processing Record 47 of Set 9 | puerto leguizamo
# Processing Record 48 of Set 9 | nanfeng
# Processing Record 49 of Set 9 | parana
# Processing Record 50 of Set 9 | fukue
# Processing Record 1 of Set 10 | christchurch
# Processing Record 2 of Set 10 | biak
# Processing Record 3 of Set 10 | yeppoon
# Processing Record 4 of Set 10 | la ronge
# Processing Record 5 of Set 10 | canelones
# Processing Record 6 of Set 10 | kuching
# Processing Record 7 of Set 10 | kamenka
# Processing Record 8 of Set 10 | balaghat
# Processing Record 9 of Set 10 | auki
# Processing Record 10 of Set 10 | mahon
# Processing Record 11 of Set 10 | nanae
# Processing Record 12 of Set 10 | kerman
# Processing Record 13 of Set 10 | jiayuguan
# Processing Record 14 of Set 10 | carlagan
# Processing Record 15 of Set 10 | kobryn
# Processing Record 16 of Set 10 | tanout
# Processing Record 17 of Set 10 | napanee
# Processing Record 18 of Set 10 | hervey bay
# Processing Record 19 of Set 10 | zhezkazgan
# Processing Record 20 of Set 10 | necochea
# Processing Record 21 of Set 10 | cauquenes
# Processing Record 22 of Set 10 | perleberg
# Processing Record 23 of Set 10 | vidalia
# Processing Record 24 of Set 10 | alofi
# Processing Record 25 of Set 10 | tuatapere
# Processing Record 26 of Set 10 | kattivakkam
# Processing Record 27 of Set 10 | aligudarz
# Processing Record 28 of Set 10 | along
# Processing Record 29 of Set 10 | atar
# Processing Record 30 of Set 10 | santa cruz
# Processing Record 31 of Set 10 | carutapera
# Processing Record 32 of Set 10 | hay river
# Processing Record 33 of Set 10 | ixtapa
# Processing Record 34 of Set 10 | coihaique
# Processing Record 35 of Set 10 | cap malheureux
# Processing Record 36 of Set 10 | tukrah
# Processing Record 37 of Set 10 | aleksandrovskoye
# Processing Record 38 of Set 10 | neenah
# Processing Record 39 of Set 10 | makat
# Processing Record 40 of Set 10 | general roca
# Processing Record 41 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 10 | palana
# Processing Record 44 of Set 10 | sao miguel do araguaia
# Processing Record 45 of Set 10 | haapiti
# Processing Record 46 of Set 10 | owando
# Processing Record 47 of Set 10 | dhidhdhoo
# Processing Record 48 of Set 10 | chapais
# Processing Record 49 of Set 10 | bon accord
# Processing Record 50 of Set 10 | sidi ali
# Processing Record 1 of Set 11 | jubayl
# City not found. Skipping...
# Processing Record 2 of Set 11 | alangudi
# Processing Record 3 of Set 11 | guerrero negro
# Processing Record 4 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 11 | pangody
# Processing Record 6 of Set 11 | zemio
# Processing Record 7 of Set 11 | ondjiva
# Processing Record 8 of Set 11 | bilaspur
# Processing Record 9 of Set 11 | mtambile
# Processing Record 10 of Set 11 | marzuq
# Processing Record 11 of Set 11 | aklavik
# Processing Record 12 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 11 | svetlogorsk
# Processing Record 14 of Set 11 | hearst
# Processing Record 15 of Set 11 | acapulco
# Processing Record 16 of Set 11 | arvika
# Processing Record 17 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 11 | lavumisa
# Processing Record 19 of Set 11 | cirie
# Processing Record 20 of Set 11 | jalu
# Processing Record 21 of Set 11 | shyroke
# Processing Record 22 of Set 11 | maba
# Processing Record 23 of Set 11 | bosanska kostajnica
# Processing Record 24 of Set 11 | saint leonard
# Processing Record 25 of Set 11 | novaya igirma
# Processing Record 26 of Set 11 | bela
# Processing Record 27 of Set 11 | okhotsk
# Processing Record 28 of Set 11 | adeje
# Processing Record 29 of Set 11 | san policarpo
# Processing Record 30 of Set 11 | muravlenko
# Processing Record 31 of Set 11 | faanui
# Processing Record 32 of Set 11 | rantepao
# Processing Record 33 of Set 11 | ribeira brava
# Processing Record 34 of Set 11 | keita
# Processing Record 35 of Set 11 | hai phong
# City not found. Skipping...
# Processing Record 36 of Set 11 | quatre cocos
# Processing Record 37 of Set 11 | codajas
# Processing Record 38 of Set 11 | sandwick
# Processing Record 39 of Set 11 | wick
# Processing Record 40 of Set 11 | helong
# Processing Record 41 of Set 11 | neumunster
# Processing Record 42 of Set 11 | tiarei
# Processing Record 43 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 11 | sinnamary
# Processing Record 45 of Set 11 | zlocieniec
# Processing Record 46 of Set 11 | nelson bay
# Processing Record 47 of Set 11 | batagay-alyta
# Processing Record 48 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 11 | yanam
# Processing Record 50 of Set 11 | daru
# Processing Record 1 of Set 12 | araxa
# Processing Record 2 of Set 12 | birao
# Processing Record 3 of Set 12 | whyalla
# Processing Record 4 of Set 12 | cajetina
# Processing Record 5 of Set 12 | roanoke rapids
# Processing Record 6 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 12 | torzhok
# Processing Record 8 of Set 12 | akdepe
# Processing Record 9 of Set 12 | lashio
# Processing Record 10 of Set 12 | monchegorsk
# Processing Record 11 of Set 12 | ploemeur
# Processing Record 12 of Set 12 | makakilo city
# Processing Record 13 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 12 | cururupu
# Processing Record 15 of Set 12 | akyab
# Processing Record 16 of Set 12 | melivoia
# Processing Record 17 of Set 12 | aswan
# Processing Record 18 of Set 12 | la playa
# Processing Record 19 of Set 12 | batagay
# Processing Record 20 of Set 12 | tygda
# Processing Record 21 of Set 12 | yumen
# Processing Record 22 of Set 12 | tura
# Processing Record 23 of Set 12 | kendari
# Processing Record 24 of Set 12 | lynn haven
# Processing Record 25 of Set 12 | ossora
# Processing Record 26 of Set 12 | lata
# Processing Record 27 of Set 12 | geneva
# Processing Record 28 of Set 12 | te anau
# Processing Record 29 of Set 12 | nehe
# Processing Record 30 of Set 12 | ulaangom
# Processing Record 31 of Set 12 | gouyave
# Processing Record 32 of Set 12 | brae
# Processing Record 33 of Set 12 | esna
# Processing Record 34 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 35 of Set 12 | pinerovka
# Processing Record 36 of Set 12 | nakamura
# Processing Record 37 of Set 12 | lanciano
# Processing Record 38 of Set 12 | saint-pierre
# Processing Record 39 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 40 of Set 12 | mocuba
# Processing Record 41 of Set 12 | ashland
# Processing Record 42 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 43 of Set 12 | buluang
# Processing Record 44 of Set 12 | souillac
# Processing Record 45 of Set 12 | aripuana
# Processing Record 46 of Set 12 | manokwari
# Processing Record 47 of Set 12 | guasdualito
# Processing Record 48 of Set 12 | kirovsk
# Processing Record 49 of Set 12 | hofn
# Processing Record 50 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 1 of Set 13 | taonan
# Processing Record 2 of Set 13 | jaciara
# Processing Record 3 of Set 13 | gainesville
# Processing Record 4 of Set 13 | morshansk
# Processing Record 5 of Set 13 | srandakan
# Processing Record 6 of Set 13 | sangmelima
# Processing Record 7 of Set 13 | methana
# Processing Record 8 of Set 13 | kinkala
# Processing Record 9 of Set 13 | evensk
# Processing Record 10 of Set 13 | salto
# Processing Record 11 of Set 13 | berdigestyakh
# Processing Record 12 of Set 13 | barranca
# Processing Record 13 of Set 13 | ust-nera
# Processing Record 14 of Set 13 | jacareacanga
# Processing Record 15 of Set 13 | aras
# Processing Record 16 of Set 13 | la orilla
# Processing Record 17 of Set 13 | gorontalo
# Processing Record 18 of Set 13 | jabinyanah
# Processing Record 19 of Set 13 | kapit
# Processing Record 20 of Set 13 | roseburg
# Processing Record 21 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 22 of Set 13 | alassio
# Processing Record 23 of Set 13 | machachi
# Processing Record 24 of Set 13 | hastings
# Processing Record 25 of Set 13 | mount gambier
# Processing Record 26 of Set 13 | davidson
# Processing Record 27 of Set 13 | mehamn
# Processing Record 28 of Set 13 | saint-orens-de-gameville
# Processing Record 29 of Set 13 | sobolevo
# Processing Record 30 of Set 13 | nemuro
# Processing Record 31 of Set 13 | nipawin
# Processing Record 32 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 13 | chernyshevskiy
# Processing Record 34 of Set 13 | nieuw nickerie
# Processing Record 35 of Set 13 | hambantota
# Processing Record 36 of Set 13 | whitecourt
# Processing Record 37 of Set 13 | burica
# City not found. Skipping...
# Processing Record 38 of Set 13 | dondo
# Processing Record 39 of Set 13 | goundam
# Processing Record 40 of Set 13 | callaguip
# Processing Record 41 of Set 13 | qarqin
# Processing Record 42 of Set 13 | port lincoln
# Processing Record 43 of Set 13 | chickasha
# Processing Record 44 of Set 13 | chaoyang
# Processing Record 45 of Set 13 | den helder
# Processing Record 46 of Set 13 | cambe
# Processing Record 47 of Set 13 | faya
# Processing Record 48 of Set 13 | lorengau
# Processing Record 49 of Set 13 | morgan city
# Processing Record 50 of Set 13 | merauke
# Processing Record 1 of Set 14 | zhangye
# Processing Record 2 of Set 14 | lavrentiya
# Processing Record 3 of Set 14 | jardim
# Processing Record 4 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 14 | pisco
# Processing Record 6 of Set 14 | amapa
# Processing Record 7 of Set 14 | tashtyp
# Processing Record 8 of Set 14 | maxixe
# Processing Record 9 of Set 14 | emba
# Processing Record 10 of Set 14 | wana
# Processing Record 11 of Set 14 | sola
# Processing Record 12 of Set 14 | green valley
# Processing Record 13 of Set 14 | ginda
# Processing Record 14 of Set 14 | talavera de la reina
# Processing Record 15 of Set 14 | araripe
# Processing Record 16 of Set 14 | harnai
# Processing Record 17 of Set 14 | millau
# Processing Record 18 of Set 14 | kiama
# Processing Record 19 of Set 14 | ko samui
# Processing Record 20 of Set 14 | hammerfest
# Processing Record 21 of Set 14 | moerai
# Processing Record 22 of Set 14 | kindu
# Processing Record 23 of Set 14 | netivot
# Processing Record 24 of Set 14 | belinskiy
# Processing Record 25 of Set 14 | egvekinot
# Processing Record 26 of Set 14 | salinopolis
# Processing Record 27 of Set 14 | castrovillari
# Processing Record 28 of Set 14 | madaoua
# Processing Record 29 of Set 14 | meulaboh
# Processing Record 30 of Set 14 | polunochnoye
# Processing Record 31 of Set 14 | bonavista
# Processing Record 32 of Set 14 | port augusta
# Processing Record 33 of Set 14 | hede
# Processing Record 34 of Set 14 | oum hadjer
# Processing Record 35 of Set 14 | rubtsovsk
# Processing Record 36 of Set 14 | dudinka
# Processing Record 37 of Set 14 | lingao
# Processing Record 38 of Set 14 | tulun
# Processing Record 39 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 14 | mitsamiouli
# Processing Record 41 of Set 14 | ilhabela
# Processing Record 42 of Set 14 | wuchi
# Processing Record 43 of Set 14 | gornoye loo
# Processing Record 44 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 14 | sergeyevka
# Processing Record 46 of Set 14 | omsukchan
# Processing Record 47 of Set 14 | san andres
# Processing Record 48 of Set 14 | peachland
# Processing Record 49 of Set 14 | udachnyy
# Processing Record 50 of Set 14 | khetia
# Processing Record 1 of Set 15 | ugoofaaru
# Processing Record 2 of Set 15 | antioch
# Processing Record 3 of Set 15 | villazon
# Processing Record 4 of Set 15 | chuguyevka
# Processing Record 5 of Set 15 | denpasar
# Processing Record 6 of Set 15 | kaneohe
# Processing Record 7 of Set 15 | wageningen
# Processing Record 8 of Set 15 | teknaf
# Processing Record 9 of Set 15 | pochutla
# Processing Record 10 of Set 15 | north myrtle beach
# Processing Record 11 of Set 15 | jingcheng
# Processing Record 12 of Set 15 | chimbote
# Processing Record 13 of Set 15 | balurghat
# Processing Record 14 of Set 15 | bitung
# Processing Record 15 of Set 15 | barra dos coqueiros
# Processing Record 16 of Set 15 | luorong
# Processing Record 17 of Set 15 | aksarayskiy
# Processing Record 18 of Set 15 | guanica
# Processing Record 19 of Set 15 | onguday
# Processing Record 20 of Set 15 | menongue
# Processing Record 21 of Set 15 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 22 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 23 of Set 15 | piacabucu
# Processing Record 24 of Set 15 | primorsk
# Processing Record 25 of Set 15 | harlingen
# Processing Record 26 of Set 15 | celestun
# Processing Record 27 of Set 15 | bima
# Processing Record 28 of Set 15 | mwanza
# Processing Record 29 of Set 15 | okha
# Processing Record 30 of Set 15 | jiujiang
# Processing Record 31 of Set 15 | vestmannaeyjar
# Processing Record 32 of Set 15 | fethiye
# Processing Record 33 of Set 15 | paka
# Processing Record 34 of Set 15 | senneterre
# Processing Record 35 of Set 15 | porto novo
# Processing Record 36 of Set 15 | solnechnyy
# Processing Record 37 of Set 15 | anloga
# Processing Record 38 of Set 15 | batemans bay
# Processing Record 39 of Set 15 | vardo
# Processing Record 40 of Set 15 | esso
# Processing Record 41 of Set 15 | doha
# Processing Record 42 of Set 15 | aksu
# Processing Record 43 of Set 15 | fairbanks
# Processing Record 44 of Set 15 | bulgan
# Processing Record 45 of Set 15 | maryborough
# Processing Record 46 of Set 15 | ohara
# Processing Record 47 of Set 15 | praia da vitoria
# Processing Record 48 of Set 15 | sao joao da barra
# Processing Record 49 of Set 15 | songjianghe
# Processing Record 50 of Set 15 | kangaatsiaq
# Processing Record 1 of Set 16 | agdam
# Processing Record 2 of Set 16 | chaman
# Processing Record 3 of Set 16 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 16 | labuhan
# Processing Record 5 of Set 16 | griffith
# Processing Record 6 of Set 16 | lusambo
# Processing Record 7 of Set 16 | kaeo
# Processing Record 8 of Set 16 | broome
# Processing Record 9 of Set 16 | turukhansk
# Processing Record 10 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 16 | praia
# Processing Record 12 of Set 16 | tamandare
# Processing Record 13 of Set 16 | miramar
# Processing Record 14 of Set 16 | albert lea
# Processing Record 15 of Set 16 | bayan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Dargaville      NZ -35.9333  173.8833     64.72        88          84
# 1         Vaini      TO -21.2000 -175.2000     75.36       100          40
# 2    Brigantine      US  39.4101  -74.3646     33.15        74          75
# 3     Busselton      AU -33.6500  115.3333     65.05        72           0
# 4     Mahebourg      MU -20.4081   57.7000     78.26        94          75
# ..          ...     ...      ...       ...       ...       ...         ...
# 700       Praia      CV  14.9215  -23.5087     75.74        64          75
# 701   Tamandare      BR  -8.7597  -35.1047     83.05        69          26
# 702     Miramar      US  25.9873  -80.2323     84.97        67          75
# 703  Albert Lea      US  43.6480  -93.3683      5.09        92           0
# 704       Bayan      CN  46.0833  127.4000     -0.11        99         100
#
#      Wind Speed Current Description
# 0          4.03       broken clouds
# 1          3.44    scattered clouds
# 2         28.77       broken clouds
# 3          8.28           clear sky
# 4          3.44       broken clouds
# ..          ...                 ...
# 700       20.71       broken clouds
# 701       12.10    scattered clouds
# 702        3.00       broken clouds
# 703       10.36           clear sky
# 704        2.77     overcast clouds
#
# [705 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = ("C:/Users/Ruth/OneDrive/Desktop/Class_Work/Module_6/HW6_Submission_Python_APIs/Weather_Database/WeatherPy_Database.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
