# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("C:/Users/Ruth/OneDrive/Desktop/Class_Work/Module_6/HW6_Submission_Python_APIs/Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Dargaville      NZ -35.9333  173.8833     64.72        88
# 1        1       Vaini      TO -21.2000 -175.2000     75.36       100
# 2        2  Brigantine      US  39.4101  -74.3646     33.15        74
# 3        3   Busselton      AU -33.6500  115.3333     65.05        72
# 4        4   Mahebourg      MU -20.4081   57.7000     78.26        94
#
#    Cloudiness  Wind Speed Current Description
# 0          84        4.03       broken clouds
# 1          40        3.44    scattered clouds
# 2          75       28.77       broken clouds
# 3           0        8.28           clear sky
# 4          75        3.44       broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 1         1            Vaini      TO -21.2000 -175.2000     75.36       100
# 4         4        Mahebourg      MU -20.4081   57.7000     78.26        94
# 10       10       Georgetown      MY   5.4112  100.3354     80.53        88
# 14       14       Butaritari      KI   3.0707  172.7902     80.78        79
# 18       18          Rikitea      PF -23.1203 -134.9692     77.49        76
# 25       25       Bluefields      NI  12.0137  -83.7635     84.27        70
# 28       28           Rawson      AR -43.3002  -65.1023     88.75        29
# 31       31  Bambous Virieux      MU -20.3428   57.7575     78.22        94
# 32       32           Atuona      PF  -9.8000 -139.0333     78.04        70
# 33       33        Cape Town      ZA -33.9258   18.4232     80.28        59
#
#     Cloudiness  Wind Speed Current Description
# 1           40        3.44    scattered clouds
# 4           75        3.44       broken clouds
# 10          20        0.00          few clouds
# 14         100       16.62       moderate rain
# 18         100       16.75          light rain
# 25          75        6.91       broken clouds
# 28           1        3.51           clear sky
# 31          75        3.44       broken clouds
# 32          23       16.46          few clouds
# 33           0        1.99           clear sky

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                204
# City                   204
# Country                203
# Lat                    204
# Lng                    204
# Max Temp               204
# Humidity               204
# Cloudiness             204
# Wind Speed             204
# Current Description    204
# dtype: int64

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID                0
# City                   0
# Country                1
# Lat                    0
# Lng                    0
# Max Temp               0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Current Description    0
# dtype: int64

# %%
preferred_cities_df
# Out:
#      City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1       Vaini      TO -21.2000 -175.2000     75.36       100
# 4          4   Mahebourg      MU -20.4081   57.7000     78.26        94
# 10        10  Georgetown      MY   5.4112  100.3354     80.53        88
# 14        14  Butaritari      KI   3.0707  172.7902     80.78        79
# 18        18     Rikitea      PF -23.1203 -134.9692     77.49        76
# ..       ...         ...     ...      ...       ...       ...       ...
# 694      694     Labuhan      ID  -6.8844  112.2051     77.29        83
# 696      696     Lusambo      CD  -4.9667   23.4500     75.31        83
# 700      700       Praia      CV  14.9215  -23.5087     75.74        64
# 701      701   Tamandare      BR  -8.7597  -35.1047     83.05        69
# 702      702     Miramar      US  25.9873  -80.2323     84.97        67
#
#      Cloudiness  Wind Speed Current Description
# 1            40        3.44    scattered clouds
# 4            75        3.44       broken clouds
# 10           20        0.00          few clouds
# 14          100       16.62       moderate rain
# 18          100       16.75          light rain
# ..          ...         ...                 ...
# 694          98        8.55     overcast clouds
# 696         100        2.51          light rain
# 700          75       20.71       broken clouds
# 701          26       12.10    scattered clouds
# 702          75        3.00       broken clouds
#
# [204 rows x 10 columns]

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1       Vaini      TO -21.2000 -175.2000     75.36       100
# 4          4   Mahebourg      MU -20.4081   57.7000     78.26        94
# 10        10  Georgetown      MY   5.4112  100.3354     80.53        88
# 14        14  Butaritari      KI   3.0707  172.7902     80.78        79
# 18        18     Rikitea      PF -23.1203 -134.9692     77.49        76
# ..       ...         ...     ...      ...       ...       ...       ...
# 694      694     Labuhan      ID  -6.8844  112.2051     77.29        83
# 696      696     Lusambo      CD  -4.9667   23.4500     75.31        83
# 700      700       Praia      CV  14.9215  -23.5087     75.74        64
# 701      701   Tamandare      BR  -8.7597  -35.1047     83.05        69
# 702      702     Miramar      US  25.9873  -80.2323     84.97        67
#
#      Cloudiness  Wind Speed Current Description
# 1            40        3.44    scattered clouds
# 4            75        3.44       broken clouds
# 10           20        0.00          few clouds
# 14          100       16.62       moderate rain
# 18          100       16.75          light rain
# ..          ...         ...                 ...
# 694          98        8.55     overcast clouds
# 696         100        2.51          light rain
# 700          75       20.71       broken clouds
# 701          26       12.10    scattered clouds
# 702          75        3.00       broken clouds
#
# [203 rows x 10 columns]

# %%
clean_df.count()
# Out:
# City_ID                203
# City                   203
# Country                203
# Lat                    203
# Lng                    203
# Max Temp               203
# Humidity               203
# Cloudiness             203
# Wind Speed             203
# Current Description    203
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 1             Vaini      TO     75.36    scattered clouds -21.2000 -175.2000
# 4         Mahebourg      MU     78.26       broken clouds -20.4081   57.7000
# 10       Georgetown      MY     80.53          few clouds   5.4112  100.3354
# 14       Butaritari      KI     80.78       moderate rain   3.0707  172.7902
# 18          Rikitea      PF     77.49          light rain -23.1203 -134.9692
# 25       Bluefields      NI     84.27       broken clouds  12.0137  -83.7635
# 28           Rawson      AR     88.75           clear sky -43.3002  -65.1023
# 31  Bambous Virieux      MU     78.22       broken clouds -20.3428   57.7575
# 32           Atuona      PF     78.04          few clouds  -9.8000 -139.0333
# 33        Cape Town      ZA     80.28           clear sky -33.9258   18.4232
#
#    Hotel Name
# 1
# 4
# 10
# 14
# 18
# 25
# 28
# 31
# 32
# 33

# %%
import numpy as np
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        #hotel_df.loc[index, "Hotel Name"] = np.NaN
        print("Hotel not found... skipping.")
print("Complete")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Complete

# %%
hotel_df.count()
# Out:
# City                   203
# Country                203
# Max Temp               203
# Current Description    203
# Lat                    203
# Lng                    203
# Hotel Name             203
# dtype: int64

# %%
hotel_df.head(25)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 1             Vaini      TO     75.36    scattered clouds -21.2000 -175.2000
# 4         Mahebourg      MU     78.26       broken clouds -20.4081   57.7000
# 10       Georgetown      MY     80.53          few clouds   5.4112  100.3354
# 14       Butaritari      KI     80.78       moderate rain   3.0707  172.7902
# 18          Rikitea      PF     77.49          light rain -23.1203 -134.9692
# 25       Bluefields      NI     84.27       broken clouds  12.0137  -83.7635
# 28           Rawson      AR     88.75           clear sky -43.3002  -65.1023
# 31  Bambous Virieux      MU     78.22       broken clouds -20.3428   57.7575
# 32           Atuona      PF     78.04          few clouds  -9.8000 -139.0333
# 33        Cape Town      ZA     80.28           clear sky -33.9258   18.4232
# 36          Kahului      US     75.85           clear sky  20.8947 -156.4700
# 39  Charters Towers      AU     78.66          few clouds -20.1000  146.2667
# 42     Puerto Ayora      EC     82.36     overcast clouds  -0.7393  -90.3518
# 45         Mokobeng      BW     77.88     overcast clouds -22.9965   27.6678
# 46             Raga      SS     80.17       broken clouds   8.4596   25.6780
# 53   Saint-Philippe      RE     77.22     overcast clouds -21.3585   55.7679
# 55        Inhambane      MZ     78.78          few clouds -23.8650   35.3833
# 60      Bandarbeyla      SO     76.55    scattered clouds   9.4942   50.8122
# 62            Nioro      GM     85.64           clear sky  13.3500  -15.7500
# 63  Arraial Do Cabo      BR     78.66       broken clouds -22.9661  -42.0278
# 68             Chuy      UY     75.99       broken clouds -33.6971  -53.4616
# 69     Key Biscayne      US     84.02       broken clouds  25.6937  -80.1628
# 72          Prestea      GH     80.13       broken clouds   5.4327   -2.1428
# 74          Itarema      BR     84.56          few clouds  -2.9248  -39.9167
# 78            Praya      CV     75.74       broken clouds  14.9215  -23.5087
#
#                               Hotel Name
# 1                    Keleti Beach Resort
# 4     Shandrani Beachcomber Resort & Spa
# 10                        Cititel Penang
# 14                    Isles Sunset Lodge
# 18                       People ThankYou
# 25     Nicaraguan Typical House Downtown
# 28                     Hosteria Sampedro
# 31                        Casa Tia Villa
# 32                           Villa Enata
# 33     Southern Sun Waterfront Cape Town
# 36                    Maui Seaside Hotel
# 39            Cattleman's Rest Motor Inn
# 42             Finch Bay Galapagos Hotel
# 45                    Omphile B. Molefhe
# 46
# 53          Chambres d'hôte "La Trinité"
# 55                                Oceano
# 60                           JABIR HOTEL
# 62
# 63                   Pousada Porto Praia
# 68                     Nuevo Hotel Plaza
# 69  The Ritz-Carlton Key Biscayne, Miami
# 72                     Garden Hill Hotel
# 74    Sea Lounge! Bar, Club & Restaurant
# 78                         LT Aparthotel

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.replace("", np.NaN, inplace= True)
hotel_df.head(25)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 1             Vaini      TO     75.36    scattered clouds -21.2000 -175.2000
# 4         Mahebourg      MU     78.26       broken clouds -20.4081   57.7000
# 10       Georgetown      MY     80.53          few clouds   5.4112  100.3354
# 14       Butaritari      KI     80.78       moderate rain   3.0707  172.7902
# 18          Rikitea      PF     77.49          light rain -23.1203 -134.9692
# 25       Bluefields      NI     84.27       broken clouds  12.0137  -83.7635
# 28           Rawson      AR     88.75           clear sky -43.3002  -65.1023
# 31  Bambous Virieux      MU     78.22       broken clouds -20.3428   57.7575
# 32           Atuona      PF     78.04          few clouds  -9.8000 -139.0333
# 33        Cape Town      ZA     80.28           clear sky -33.9258   18.4232
# 36          Kahului      US     75.85           clear sky  20.8947 -156.4700
# 39  Charters Towers      AU     78.66          few clouds -20.1000  146.2667
# 42     Puerto Ayora      EC     82.36     overcast clouds  -0.7393  -90.3518
# 45         Mokobeng      BW     77.88     overcast clouds -22.9965   27.6678
# 46             Raga      SS     80.17       broken clouds   8.4596   25.6780
# 53   Saint-Philippe      RE     77.22     overcast clouds -21.3585   55.7679
# 55        Inhambane      MZ     78.78          few clouds -23.8650   35.3833
# 60      Bandarbeyla      SO     76.55    scattered clouds   9.4942   50.8122
# 62            Nioro      GM     85.64           clear sky  13.3500  -15.7500
# 63  Arraial Do Cabo      BR     78.66       broken clouds -22.9661  -42.0278
# 68             Chuy      UY     75.99       broken clouds -33.6971  -53.4616
# 69     Key Biscayne      US     84.02       broken clouds  25.6937  -80.1628
# 72          Prestea      GH     80.13       broken clouds   5.4327   -2.1428
# 74          Itarema      BR     84.56          few clouds  -2.9248  -39.9167
# 78            Praya      CV     75.74       broken clouds  14.9215  -23.5087
#
#                               Hotel Name
# 1                    Keleti Beach Resort
# 4     Shandrani Beachcomber Resort & Spa
# 10                        Cititel Penang
# 14                    Isles Sunset Lodge
# 18                       People ThankYou
# 25     Nicaraguan Typical House Downtown
# 28                     Hosteria Sampedro
# 31                        Casa Tia Villa
# 32                           Villa Enata
# 33     Southern Sun Waterfront Cape Town
# 36                    Maui Seaside Hotel
# 39            Cattleman's Rest Motor Inn
# 42             Finch Bay Galapagos Hotel
# 45                    Omphile B. Molefhe
# 46                                   NaN
# 53          Chambres d'hôte "La Trinité"
# 55                                Oceano
# 60                           JABIR HOTEL
# 62                                   NaN
# 63                   Pousada Porto Praia
# 68                     Nuevo Hotel Plaza
# 69  The Ritz-Carlton Key Biscayne, Miami
# 72                     Garden Hill Hotel
# 74    Sea Lounge! Bar, Club & Restaurant
# 78                         LT Aparthotel

# %%
hotel_df.count()
# Out:
# City                   203
# Country                203
# Max Temp               203
# Current Description    203
# Lat                    203
# Lng                    203
# Hotel Name             184
# dtype: int64

# %%
clean_hotel_df = hotel_df.dropna()
clean_hotel_df
# Out:
#                   City Country  Max Temp Current Description      Lat  \
# 1                Vaini      TO     75.36    scattered clouds -21.2000
# 4            Mahebourg      MU     78.26       broken clouds -20.4081
# 10          Georgetown      MY     80.53          few clouds   5.4112
# 14          Butaritari      KI     80.78       moderate rain   3.0707
# 18             Rikitea      PF     77.49          light rain -23.1203
# ..                 ...     ...       ...                 ...      ...
# 689  Sao Joao Da Barra      BR     75.29     overcast clouds -21.6403
# 694            Labuhan      ID     77.29     overcast clouds  -6.8844
# 700              Praia      CV     75.74       broken clouds  14.9215
# 701          Tamandare      BR     83.05    scattered clouds  -8.7597
# 702            Miramar      US     84.97       broken clouds  25.9873
#
#           Lng                          Hotel Name
# 1   -175.2000                 Keleti Beach Resort
# 4     57.7000  Shandrani Beachcomber Resort & Spa
# 10   100.3354                      Cititel Penang
# 14   172.7902                  Isles Sunset Lodge
# 18  -134.9692                     People ThankYou
# ..        ...                                 ...
# 689  -41.0511             Pousada Porto De Canoas
# 694  112.2051                           DoubleFAG
# 700  -23.5087                       LT Aparthotel
# 701  -35.1047                  Pousada 100 Passos
# 702  -80.2323                        Casa Miramar
#
# [184 rows x 7 columns]

# %%
clean_hotel_df.count()
# Out:
# City                   184
# Country                184
# Max Temp               184
# Current Description    184
# Lat                    184
# Lng                    184
# Hotel Name             184
# dtype: int64

# %%
# 8a. Create the output File (CSV)
output_data_file = "C:/Users/Ruth/OneDrive/Desktop/Class_Work/Module_6/HW6_Submission_Python_APIs/Vacation_Search/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt> Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations,info_box_content=hotel_info)
#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Save the figure.
#fig.savefig("Vacation_Search/WeatherPy_vacation_map.png")

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
